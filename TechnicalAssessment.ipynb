# %%
# Import simple dependencies

import pandas as pd
import numpy as np

# %%
# Load file and see first 5 rows. Having seen the excel file, seeing the first 5 rows will not give much direction to what needs to be done.

df = pd.read_csv("/mnt/c/Users/user/Downloads/Technical Assessment - amalgamated_widgets_payroll.csv")
df.head()
# Out:
#                                           Unnamed: 0       Unnamed: 1  \
# 0                                                NaN              NaN
# 1                         Employee Previous Earnings              NaN
# 2                                    Payroll Company              NaN
# 3                                           001POWED  Dominick Powers
# 4  For Pay End Periods between 1/07/1982 and 25/0...              NaN
#
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2  AMALGAMATED WIDGETS - AMALGAMATED WIDGETS PTY LTD        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#     Employee Previous Earnings  Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0  AMALGAMATED WIDGETS PTY LTD         NaN         NaN         NaN        NaN
# 1                          NaN         NaN         NaN         NaN        NaN
# 2                          NaN         NaN         NaN         NaN        NaN
# 3                          NaN         NaN         NaN         NaN        NaN
# 4                          NaN         NaN         NaN         NaN        NaN
#
#   Unnamed: 10    Unnamed: 11
# 0         NaN            NaN
# 1         NaN  Page 1 of 553
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN

# %% [markdown]
# # Things to note after looking at data:
#
# 1. "Pay frequency" seems to always be "1W01 - Weekly", however the column cannot be removed just yet as it contains employee names.
# 2. "Location" also seems to always be "CARCOSA", meaning the whole column is redundant.
# 3. The column with "Number of" contains (at all times) "Normal Hours", "Gross Taxable Total",  "Tax (Incl Adjust)", and "Net Pay".
#
# Thus, my idea is to create a new dataframe, with features: EmployeeID, EmployeeName, PayDate, and other important features that each pay will have differently.

# %%
# 1. "Pay frequency" seems to always be "1W01 - Weekly", however the column cannot be removed just yet as it contains employee names. (TRUE)

print(df.iloc[:, 1].unique())
# Out:
# [nan 'Dominick Powers' 'Pay Frequency' '1W01 - Weekly' 'Crystal Morin'
#  'Erma Dalton' 'Kristy Nash' 'Henrietta Randall' 'Avis Browning'
#  'Abigail Gaines' 'Randell Calhoun' 'Garry Kent' 'Melanie Golden'
#  'Jonathan Mcconnell' 'Merrill Gamble' 'Mauro Dixon' 'Sara Ellis'
#  'Phil Rush' 'Beth Lucas' 'Nola Sims' 'Larry Delaney' 'Christy Mcintyre'
#  'Milo Lyons' 'Luann Moody' 'Hans Torres' 'Velma Alford' 'Imogene Delgado'
#  'Irving Pace' 'Georgina Ellison' 'Corinne Bryant' 'Stefan Miles'
#  'Simon Ball' 'Rosanna Conway' 'Charley Montgomery' 'Cathy Beard'
#  'Ryan Todd' 'Sammy Williamson' 'Eunice Rodriguez' 'Mercedes Dean'
#  'Brandie Wall' 'Ethel Carney' 'Leonel Carson' 'Luz Mendez' 'Etta Kerr'
#  'Claudio George' 'Anibal Lucas' 'Charlie Figueroa' 'Bertha West'
#  'Leanne Mcgowan' 'Tamara Bailey' 'Patty Lowe']

# %%
# 2. "Location" also seems to always be "CARCOSA", meaning the whole column is redundant. (TRUE)

print(df.iloc[:, 3].unique())
# Out:
# [nan 'Location' 'CARCOSA']

# %%
# Test if date matches regex

import re

regex_date = r'^\d{1,2}/\d{1,2}/\d{2,4}$'

for row in df.iloc[:, 0]:
    if isinstance(row, str) and re.match(regex_date, row):
        print(row)
# Out:
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 10/01/1983
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 7/02/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 22/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 12/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 30/01/1984
# 13/03/1984
# 27/03/1984
# 10/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 22/05/1984
# 5/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 21/08/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 24/01/1983
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 5/07/1982
# 15/05/1984
# 22/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 17/01/1983
# 24/01/1983
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 15/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 6/11/1984
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 24/07/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 5/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 29/11/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 10/04/1984
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 27/06/1983
# 1/08/1983
# 8/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 10/04/1984
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 26/12/1983
# 16/01/1984
# 27/02/1984
# 1/05/1984
# 30/10/1984
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 20/02/1984
# 27/02/1984
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 4/06/1985
# 18/06/1985
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 23/10/1984
# 18/12/1984
# 1/01/1985
# 5/02/1985
# 19/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983
# 1/08/1983
# 8/08/1983
# 15/08/1983
# 22/08/1983
# 29/08/1983
# 5/09/1983
# 12/09/1983
# 19/09/1983
# 26/09/1983
# 3/10/1983
# 10/10/1983
# 17/10/1983
# 24/10/1983
# 31/10/1983
# 7/11/1983
# 14/11/1983
# 21/11/1983
# 28/11/1983
# 5/12/1983
# 12/12/1983
# 19/12/1983
# 26/12/1983
# 2/01/1984
# 9/01/1984
# 16/01/1984
# 23/01/1984
# 30/01/1984
# 6/02/1984
# 13/02/1984
# 20/02/1984
# 27/02/1984
# 6/03/1984
# 13/03/1984
# 20/03/1984
# 27/03/1984
# 3/04/1984
# 10/04/1984
# 17/04/1984
# 24/04/1984
# 1/05/1984
# 8/05/1984
# 15/05/1984
# 22/05/1984
# 29/05/1984
# 5/06/1984
# 12/06/1984
# 19/06/1984
# 26/06/1984
# 3/07/1984
# 10/07/1984
# 17/07/1984
# 24/07/1984
# 31/07/1984
# 7/08/1984
# 14/08/1984
# 21/08/1984
# 28/08/1984
# 4/09/1984
# 11/09/1984
# 18/09/1984
# 25/09/1984
# 2/10/1984
# 9/10/1984
# 16/10/1984
# 23/10/1984
# 30/10/1984
# 6/11/1984
# 13/11/1984
# 20/11/1984
# 27/11/1984
# 4/12/1984
# 11/12/1984
# 18/12/1984
# 25/12/1984
# 1/01/1985
# 8/01/1985
# 15/01/1985
# 22/01/1985
# 29/01/1985
# 5/02/1985
# 12/02/1985
# 19/02/1985
# 26/02/1985
# 5/03/1985
# 12/03/1985
# 19/03/1985
# 26/03/1985
# 2/04/1985
# 9/04/1985
# 16/04/1985
# 23/04/1985
# 30/04/1985
# 7/05/1985
# 14/05/1985
# 21/05/1985
# 28/05/1985
# 4/06/1985
# 11/06/1985
# 18/06/1985
# 25/06/1985
# 5/07/1982
# 12/07/1982
# 19/07/1982
# 26/07/1982
# 2/08/1982
# 9/08/1982
# 16/08/1982
# 23/08/1982
# 30/08/1982
# 6/09/1982
# 13/09/1982
# 20/09/1982
# 27/09/1982
# 4/10/1982
# 11/10/1982
# 18/10/1982
# 25/10/1982
# 1/11/1982
# 8/11/1982
# 15/11/1982
# 22/11/1982
# 29/11/1982
# 6/12/1982
# 13/12/1982
# 20/12/1982
# 27/12/1982
# 3/01/1983
# 10/01/1983
# 17/01/1983
# 24/01/1983
# 31/01/1983
# 7/02/1983
# 14/02/1983
# 21/02/1983
# 28/02/1983
# 7/03/1983
# 14/03/1983
# 21/03/1983
# 28/03/1983
# 4/04/1983
# 11/04/1983
# 18/04/1983
# 25/04/1983
# 2/05/1983
# 9/05/1983
# 16/05/1983
# 23/05/1983
# 30/05/1983
# 6/06/1983
# 13/06/1983
# 20/06/1983
# 27/06/1983
# 4/07/1983
# 11/07/1983
# 18/07/1983
# 25/07/1983

# %%
# Function to extract all payroll data for all employees.

import re

payroll_index = []
entries = []
regex_date = r'^\d{1,2}/\d{1,2}/\d{2,4}$'
features = []

def PayInstanceEntry(df_input):
    for idx, row in df_input.iterrows():
        if row[0] == 'Payroll Company':
            payroll_index.append(idx)   # Separates instances of pays using the appearance of "Payroll Company"
    
    for i in range(len(payroll_index) - 1):
        emp_prev_earnings = df[payroll_index[i]+1 : payroll_index[i+1]]
        emp_id = emp_prev_earnings.iloc[0,0] 
        emp_name = emp_prev_earnings.iloc[0,1] # Directly below "Payroll company" is Employee ID and to the right of it Employee Name
        
        for ep_idx in range(len(emp_prev_earnings)):
            ep_row = emp_prev_earnings.iloc[ep_idx]
            if isinstance(ep_row[0], str) and re.match(regex_date, ep_row[0]): # Finds dates in first column
                pay_date = ep_row[0]
                entry = [pay_date, emp_id, emp_name]
                while ep_idx < len(emp_prev_earnings) and pd.isna(emp_prev_earnings.iloc[ep_idx + 1, 0]):
                    entry.append([
                        emp_prev_earnings.iloc[ep_idx + 1, 5], 
                        emp_prev_earnings.iloc[ep_idx + 1, 10], 
                        emp_prev_earnings.iloc[ep_idx + 1, 11]
                    ])
                    if emp_prev_earnings.iloc[ep_idx + 1, 5] not in features:
                        features.append(emp_prev_earnings.iloc[ep_idx + 1, 5])
                    ep_idx += 1 #Iterates through the values below the date, if they are null, take the values on the right, and keep going
                entries.append(entry)

# %%
PayInstanceEntry(df)

# %%
# List of entries
entries
# Out:
# [['6/12/1982',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '23', '351.87'],
#   ['Gross Taxable Total', '0', '351.87'],
#   ['Tax (Incl Adjust)', '0', '0'],
#   ['Net Pay', '0', '351.87']],
#  ['13/12/1982',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '46', '703.74'],
#   ['Gross Taxable Total', '0', '703.74'],
#   ['Tax (Incl Adjust)', '0', '-80'],
#   ['Net Pay', '0', '623.74'],
#   ['Superannuation', '0', '66.86']],
#  ['20/12/1982',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '37.5', '573.7'],
#   ['Gross Taxable Total', '0', '573.7'],
#   ['Tax (Incl Adjust)', '0', '-53'],
#   ['Net Pay', '0', '520.7'],
#   ['Superannuation', '0', '54.5']],
#  ['27/12/1982',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '30', '458.96'],
#   ['Public Holiday - worked', '15', '573.7'],
#   ['Gross Taxable Total', '0', '1032.66'],
#   ['Tax (Incl Adjust)', '0', '-194'],
#   ['Net Pay', '0', '838.66'],
#   ['Superannuation', '0', '98.1']],
#  ['3/01/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '37.5', '573.7'],
#   ['Gross Taxable Total', '0', '573.7'],
#   ['Tax (Incl Adjust)', '0', '-53'],
#   ['Net Pay', '0', '520.7'],
#   ['Superannuation', '0', '54.5']],
#  ['10/01/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '32', '489.56'],
#   ['Time/Half Hours', '5.5', '126.21'],
#   ['Gross Taxable Total', '0', '615.77'],
#   ['Tax (Incl Adjust)', '0', '-62'],
#   ['Net Pay', '0', '553.77'],
#   ['Superannuation', '0', '46.51']],
#  ['17/01/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '31', '474.26'],
#   ['Gross Taxable Total', '0', '474.26'],
#   ['Tax (Incl Adjust)', '0', '-29'],
#   ['Net Pay', '0', '445.26'],
#   ['Superannuation', '0', '45.05']],
#  ['24/01/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '37', '566.05'],
#   ['Gross Taxable Total', '0', '566.05'],
#   ['Tax (Incl Adjust)', '0', '-52'],
#   ['Net Pay', '0', '514.05'],
#   ['Superannuation', '0', '53.77']],
#  ['31/01/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '33.5', '512.51'],
#   ['Gross Taxable Total', '0', '512.51'],
#   ['Tax (Incl Adjust)', '0', '-40'],
#   ['Net Pay', '0', '472.51'],
#   ['Superannuation', '0', '48.69']],
#  ['7/02/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '35.5', '543.1'],
#   ['Gross Taxable Total', '0', '543.1'],
#   ['Tax (Incl Adjust)', '0', '-47'],
#   ['Reimburse expenses', '0', '50'],
#   ['Net Pay', '0', '546.1'],
#   ['Superannuation', '0', '51.59']],
#  ['14/02/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '35.25', '539.28'],
#   ['Gross Taxable Total', '0', '539.28'],
#   ['Tax (Incl Adjust)', '0', '-46'],
#   ['Net Pay', '0', '493.28'],
#   ['Superannuation', '0', '51.23']],
#  ['21/02/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '34.5', '527.81'],
#   ['Gross Taxable Total', '0', '527.81'],
#   ['Tax (Incl Adjust)', '0', '-43'],
#   ['Net Pay', '0', '484.81'],
#   ['Superannuation', '0', '50.14']],
#  ['28/02/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '35.25', '539.28'],
#   ['Gross Taxable Total', '0', '539.28'],
#   ['Tax (Incl Adjust)', '0', '-46'],
#   ['Net Pay', '0', '493.28'],
#   ['Superannuation', '0', '51.23']],
#  ['7/03/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '35.5', '543.1'],
#   ['Gross Taxable Total', '0', '543.1'],
#   ['Tax (Incl Adjust)', '0', '-47'],
#   ['Net Pay', '0', '496.1'],
#   ['Superannuation', '0', '51.59']],
#  ['14/03/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '35.5', '543.1'],
#   ['Gross Taxable Total', '0', '543.1'],
#   ['Tax (Incl Adjust)', '0', '-47'],
#   ['Net Pay', '0', '496.1'],
#   ['Superannuation', '0', '51.59']],
#  ['21/03/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '35.5', '543.1'],
#   ['Gross Taxable Total', '0', '543.1'],
#   ['Tax (Incl Adjust)', '0', '-47'],
#   ['Uniforms - Reducing Balance', '0', '-11'],
#   ['Net Pay', '0', '485.1'],
#   ['Superannuation', '0', '51.59']],
#  ['28/03/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '32', '529.08'],
#   ['Gross Taxable Total', '0', '529.08'],
#   ['Tax (Incl Adjust)', '0', '-44'],
#   ['Uniforms - Reducing Balance', '0', '-11'],
#   ['Net Pay', '0', '474.08'],
#   ['Superannuation', '0', '50.26']],
#  ['4/04/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '33.25', '593.47'],
#   ['Gross Taxable Total', '0', '593.47'],
#   ['Tax (Incl Adjust)', '0', '-57'],
#   ['Uniforms - Reducing Balance', '0', '-11'],
#   ['Net Pay', '0', '525.47'],
#   ['Superannuation', '0', '56.38']],
#  ['11/04/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '41.5', '740.71'],
#   ['Gross Taxable Total', '0', '740.71'],
#   ['Tax (Incl Adjust)', '0', '-92'],
#   ['Net Pay', '0', '648.71'],
#   ['Superannuation', '0', '70.37']],
#  ['18/04/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '16.5', '294.5'],
#   ['Public Holiday - worked', '8.5', '379.28'],
#   ['Gross Taxable Total', '0', '673.78'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.78'],
#   ['Superannuation', '0', '64.01']],
#  ['25/04/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '41.75', '745.17'],
#   ['Gross Taxable Total', '0', '745.17'],
#   ['Tax (Incl Adjust)', '0', '-94'],
#   ['Net Pay', '0', '651.17'],
#   ['Superannuation', '0', '70.79']],
#  ['2/05/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '25', '446.21'],
#   ['Gross Taxable Total', '0', '446.21'],
#   ['Tax (Incl Adjust)', '0', '-21'],
#   ['Net Pay', '0', '425.21']],
#  ['9/05/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '34', '606.85'],
#   ['Gross Taxable Total', '0', '606.85'],
#   ['Tax (Incl Adjust)', '0', '-60'],
#   ['Net Pay', '0', '546.85'],
#   ['Superannuation', '0', '100.04']],
#  ['16/05/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '34', '606.85'],
#   ['Gross Taxable Total', '0', '606.85'],
#   ['Tax (Incl Adjust)', '0', '-60'],
#   ['Net Pay', '0', '546.85'],
#   ['Superannuation', '0', '57.65']],
#  ['23/05/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '14.5', '258.8'],
#   ['Gross Taxable Total', '0', '258.8'],
#   ['Tax (Incl Adjust)', '0', '0'],
#   ['Net Pay', '0', '258.8'],
#   ['Superannuation', '0', '24.59']],
#  ['30/05/1983',
#   '001POWED',
#   'Dominick Powers',
#   ['Normal Hours', '25', '446.21'],
#   ['Gross Taxable Total', '0', '446.21'],
#   ['Tax (Incl Adjust)', '0', '-21'],
#   ['Net Pay', '0', '425.21'],
#   ['Superannuation', '0', '42.39']],
#  ['16/04/1985',
#   '002MORIC',
#   'Crystal Morin',
#   ['Normal Hours', '46', '1003.22'],
#   ['Gross Taxable Total', '0', '1003.22'],
#   ['Tax (Incl Adjust)', '0', '-85'],
#   ['Net Pay', '0', '918.22'],
#   ['Superannuation', '0', '95.3']],
#  ['23/04/1985',
#   '002MORIC',
#   'Crystal Morin',
#   ['Normal Hours', '19.5', '425.27'],
#   ['Gross Taxable Total', '0', '425.27'],
#   ['Tax (Incl Adjust)', '0', '-14'],
#   ['Net Pay', '0', '411.27'],
#   ['Superannuation', '0', '40.4']],
#  ['30/04/1985',
#   '002MORIC',
#   'Crystal Morin',
#   ['Normal Hours', '30', '654.27'],
#   ['Sat Casual Ldg', '8.5', '14.83'],
#   ['Gross Taxable Total', '0', '669.1'],
#   ['Tax (Incl Adjust)', '0', '-73'],
#   ['Net Pay', '0', '596.1'],
#   ['Superannuation', '0', '63.56']],
#  ['7/05/1985',
#   '002MORIC',
#   'Crystal Morin',
#   ['Normal Hours', '4', '87.24'],
#   ['Gross Taxable Total', '0', '87.24'],
#   ['Tax (Incl Adjust)', '0', '0'],
#   ['Net Pay', '0', '87.24']],
#  ['5/07/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '792.31'],
#   ['Gross Taxable Total', '0', '792.31'],
#   ['Tax (Incl Adjust)', '0', '-110'],
#   ['Net Pay', '0', '682.31'],
#   ['Superannuation', '0', '75.27']],
#  ['12/07/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '792.31'],
#   ['Gross Taxable Total', '0', '792.31'],
#   ['Tax (Incl Adjust)', '0', '-110'],
#   ['Net Pay', '0', '682.31'],
#   ['Superannuation', '0', '75.27']],
#  ['19/07/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '792.31'],
#   ['Gross Taxable Total', '0', '792.31'],
#   ['Tax (Incl Adjust)', '0', '-110'],
#   ['Net Pay', '0', '682.31'],
#   ['Superannuation', '0', '75.27']],
#  ['26/07/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '792.31'],
#   ['Gross Taxable Total', '0', '792.31'],
#   ['Tax (Incl Adjust)', '0', '-110'],
#   ['Net Pay', '0', '682.31'],
#   ['Superannuation', '0', '75.27']],
#  ['2/08/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '792.31'],
#   ['Gross Taxable Total', '0', '792.31'],
#   ['Tax (Incl Adjust)', '0', '-110'],
#   ['Net Pay', '0', '682.31'],
#   ['Superannuation', '0', '75.27']],
#  ['9/08/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '792.31'],
#   ['Gross Taxable Total', '0', '792.31'],
#   ['Tax (Incl Adjust)', '0', '-110'],
#   ['Net Pay', '0', '682.31'],
#   ['Superannuation', '0', '75.27']],
#  ['16/08/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['23/08/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['30/08/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['6/09/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['13/09/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['20/09/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['27/09/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['4/10/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['11/10/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Reimburse expenses', '0', '76.5'],
#   ['Net Pay', '0', '793.66'],
#   ['Superannuation', '0', '80.39']],
#  ['18/10/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['25/10/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['1/11/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['8/11/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['15/11/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['22/11/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['29/11/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['6/12/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['13/12/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['20/12/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['27/12/1982',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '32', '676.92'],
#   ['Other Leave - Public Holiday', '8', '169.23'],
#   ['Gross Taxable Total', '0', '846.15'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.15'],
#   ['Superannuation', '0', '80.38']],
#  ['3/01/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['10/01/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['17/01/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['24/01/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['31/01/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['7/02/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '23.5', '497.12'],
#   ['Annual Leave', '16.5', '349.04'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['14/02/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['21/02/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['28/02/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['7/03/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['14/03/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['21/03/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['28/03/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['4/04/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '30', '634.62'],
#   ['Sick Leave', '10', '211.54'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['11/04/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Reimburse expenses', '0', '14.95'],
#   ['Net Pay', '0', '732.11'],
#   ['Superannuation', '0', '80.39']],
#  ['18/04/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '32', '676.92'],
#   ['Other Leave - Public Holiday', '8', '169.23'],
#   ['Gross Taxable Total', '0', '846.15'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.15'],
#   ['Superannuation', '0', '80.38']],
#  ['25/04/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['2/05/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['9/05/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '32.5', '687.5'],
#   ['Sick Leave', '7.5', '158.65'],
#   ['Annual Leave', '40', '846.16'],
#   ['Gross Taxable Total', '0', '1692.31'],
#   ['Tax (Incl Adjust)', '0', '-444'],
#   ['Net Pay', '0', '1248.31'],
#   ['Superannuation', '0', '160.77']],
#  ['16/05/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.15'],
#   ['Gross Taxable Total', '0', '846.15'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.15'],
#   ['Superannuation', '0', '80.38']],
#  ['23/05/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['30/05/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['6/06/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['13/06/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '32', '676.92'],
#   ['Other Leave - Birthday', '8', '169.23'],
#   ['Gross Taxable Total', '0', '846.15'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.15'],
#   ['Superannuation', '0', '80.38']],
#  ['20/06/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['27/06/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['4/07/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['11/07/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '28', '592.31'],
#   ['Sick Leave', '12', '253.85'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['18/07/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Gross Taxable Total', '0', '846.16'],
#   ['Tax (Incl Adjust)', '0', '-129'],
#   ['Net Pay', '0', '717.16'],
#   ['Superannuation', '0', '80.39']],
#  ['25/07/1983',
#   '003DALTE',
#   'Erma Dalton',
#   ['Normal Hours', '40', '846.16'],
#   ['Term AL Gross', '196.83', '4163.72'],
#   ['Gross Taxable Total', '0', '5009.88'],
#   ['Tax (Incl Adjust)', '0', '-1585'],
#   ['Account Payment', '0', '-1478.66'],
#   ['Net Pay', '0', '1946.22'],
#   ['Superannuation', '0', '80.39']],
#  ['5/07/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '567.73'],
#   ['60% Sun Perm Ldg', '7.5', '89.64'],
#   ['Gross Taxable Total', '0', '657.37'],
#   ['Tax (Incl Adjust)', '0', '-71'],
#   ['Net Pay', '0', '586.37'],
#   ['Superannuation', '0', '62.45']],
#  ['12/07/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '29', '591.55'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '683.34'],
#   ['Tax (Incl Adjust)', '0', '-76'],
#   ['Reimburse expenses', '0', '50'],
#   ['Net Pay', '0', '657.34'],
#   ['Superannuation', '0', '64.92']],
#  ['19/07/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21', '428.36'],
#   ['Sick Leave', '7.5', '152.99'],
#   ['Gross Taxable Total', '0', '581.35'],
#   ['Tax (Incl Adjust)', '0', '-55'],
#   ['Net Pay', '0', '526.35'],
#   ['Superannuation', '0', '55.23']],
#  ['26/07/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['2/08/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '25.5', '520.16'],
#   ['Annual Leave', '3', '61.19'],
#   ['60% Sun Perm Ldg', '4.5', '55.08'],
#   ['Leave Loading 17.5%', '0', '10.71'],
#   ['Gross Taxable Total', '0', '647.14'],
#   ['Tax (Incl Adjust)', '0', '-69'],
#   ['Net Pay', '0', '578.14'],
#   ['Superannuation', '0', '60.46']],
#  ['9/08/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['16/08/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['23/08/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['30/08/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '295.78'],
#   ['Annual Leave', '14', '285.58'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Leave Loading 17.5%', '0', '49.98'],
#   ['Gross Taxable Total', '0', '723.13'],
#   ['Tax (Incl Adjust)', '0', '-86'],
#   ['Net Pay', '0', '637.13'],
#   ['Superannuation', '0', '63.95']],
#  ['6/09/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '295.78'],
#   ['Sick Leave', '7', '142.79'],
#   ['Annual Leave', '7', '142.79'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Leave Loading 17.5%', '0', '24.99'],
#   ['Gross Taxable Total', '0', '698.14'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '619.14'],
#   ['Superannuation', '0', '63.95']],
#  ['13/09/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['20/09/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '27.5', '560.95'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '652.74'],
#   ['Tax (Incl Adjust)', '0', '-70'],
#   ['Net Pay', '0', '582.74'],
#   ['Superannuation', '0', '62.01']],
#  ['27/09/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['4/10/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '20.5', '418.17'],
#   ['60% Sun Perm Ldg', '6.5', '79.55'],
#   ['Public Holiday - worked', '7.5', '382.47'],
#   ['Gross Taxable Total', '0', '880.19'],
#   ['Tax (Incl Adjust)', '0', '-141'],
#   ['Net Pay', '0', '739.19'],
#   ['Superannuation', '0', '83.62']],
#  ['11/10/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '27.25', '555.85'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '647.64'],
#   ['Tax (Incl Adjust)', '0', '-69'],
#   ['Net Pay', '0', '578.64'],
#   ['Superannuation', '0', '61.53']],
#  ['18/10/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '29.25', '596.65'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '688.44'],
#   ['Tax (Incl Adjust)', '0', '-77'],
#   ['Net Pay', '0', '611.44'],
#   ['Superannuation', '0', '65.4']],
#  ['25/10/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '7', '142.79'],
#   ['Sick Leave', '14', '285.58'],
#   ['Annual Leave', '7.5', '152.99'],
#   ['Leave Loading 17.5%', '0', '26.77'],
#   ['Gross Taxable Total', '0', '608.13'],
#   ['Tax (Incl Adjust)', '0', '-60'],
#   ['Net Pay', '0', '548.13'],
#   ['Superannuation', '0', '55.23']],
#  ['1/11/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['8/11/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['15/11/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21', '428.36'],
#   ['Annual Leave', '7.5', '152.99'],
#   ['Leave Loading 17.5%', '0', '26.77'],
#   ['Gross Taxable Total', '0', '608.12'],
#   ['Tax (Incl Adjust)', '0', '-60'],
#   ['Net Pay', '0', '548.12'],
#   ['Superannuation', '0', '55.23']],
#  ['22/11/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '26.5', '540.55'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '632.34'],
#   ['Tax (Incl Adjust)', '0', '-65'],
#   ['Net Pay', '0', '567.34'],
#   ['Superannuation', '0', '60.07']],
#  ['29/11/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['6/12/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['13/12/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '26.5', '540.55'],
#   ['60% Sun Perm Ldg', '5.5', '67.31'],
#   ['Gross Taxable Total', '0', '607.86'],
#   ['Tax (Incl Adjust)', '0', '-60'],
#   ['Net Pay', '0', '547.86'],
#   ['Superannuation', '0', '57.75']],
#  ['20/12/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['27/12/1982',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14', '285.58'],
#   ['Other Leave - Public Holiday', '7.5', '152.99'],
#   ['Public Holiday - worked', '7.5', '382.47'],
#   ['Gross Taxable Total', '0', '821.04'],
#   ['Tax (Incl Adjust)', '0', '-120'],
#   ['Net Pay', '0', '701.04'],
#   ['Superannuation', '0', '78']],
#  ['3/01/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14', '285.58'],
#   ['Public Holiday - worked', '15', '764.94'],
#   ['Gross Taxable Total', '0', '1050.52'],
#   ['Tax (Incl Adjust)', '0', '-200'],
#   ['Net Pay', '0', '850.52'],
#   ['Superannuation', '0', '99.8']],
#  ['10/01/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '438.56'],
#   ['Sick Leave', '7', '142.79'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['17/01/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '7.5', '152.99'],
#   ['Annual Leave', '21', '428.37'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Leave Loading 17.5%', '0', '74.97'],
#   ['Gross Taxable Total', '0', '748.12'],
#   ['Tax (Incl Adjust)', '0', '-95'],
#   ['Net Pay', '0', '653.12'],
#   ['Superannuation', '0', '63.95']],
#  ['24/01/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '295.78'],
#   ['Annual Leave', '14', '285.58'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Leave Loading 17.5%', '0', '49.98'],
#   ['Gross Taxable Total', '0', '723.13'],
#   ['Tax (Incl Adjust)', '0', '-86'],
#   ['Net Pay', '0', '637.13'],
#   ['Superannuation', '0', '63.95']],
#  ['31/01/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '438.56'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Public Holiday - worked', '7.5', '382.47'],
#   ['Gross Taxable Total', '0', '912.82'],
#   ['Tax (Incl Adjust)', '0', '-152'],
#   ['Net Pay', '0', '760.82'],
#   ['Superannuation', '0', '86.72']],
#  ['7/02/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['14/02/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['21/02/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '295.78'],
#   ['Annual Leave', '15', '305.97'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Leave Loading 17.5%', '0', '53.55'],
#   ['Gross Taxable Total', '0', '747.09'],
#   ['Tax (Incl Adjust)', '0', '-95'],
#   ['Net Pay', '0', '652.09'],
#   ['Superannuation', '0', '65.89']],
#  ['28/02/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.75', '586.45'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '678.24'],
#   ['Tax (Incl Adjust)', '0', '-75'],
#   ['Net Pay', '0', '603.24'],
#   ['Superannuation', '0', '64.43']],
#  ['7/03/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['14/03/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '295.78'],
#   ['Sick Leave', '7', '142.79'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Public Holiday - worked', '7.5', '382.47'],
#   ['Gross Taxable Total', '0', '912.83'],
#   ['Tax (Incl Adjust)', '0', '-152'],
#   ['Net Pay', '0', '760.83'],
#   ['Superannuation', '0', '86.72']],
#  ['21/03/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['28/03/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '29', '591.55'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '683.34'],
#   ['Tax (Incl Adjust)', '0', '-76'],
#   ['Net Pay', '0', '607.34'],
#   ['Superannuation', '0', '64.92']],
#  ['4/04/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '25', '509.96'],
#   ['60% Sun Perm Ldg', '4', '48.96'],
#   ['Gross Taxable Total', '0', '558.92'],
#   ['Tax (Incl Adjust)', '0', '-50'],
#   ['Net Pay', '0', '508.92'],
#   ['Superannuation', '0', '53.1']],
#  ['11/04/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['18/04/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14', '285.58'],
#   ['Annual Leave', '7.5', '152.99'],
#   ['Other Leave - Public Holiday', '7', '142.79'],
#   ['Leave Loading 17.5%', '0', '26.77'],
#   ['Gross Taxable Total', '0', '608.13'],
#   ['Tax (Incl Adjust)', '0', '-60'],
#   ['Net Pay', '0', '548.13'],
#   ['Superannuation', '0', '55.23']],
#  ['25/04/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '7.5', '152.99'],
#   ['Annual Leave', '21', '428.37'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Leave Loading 17.5%', '0', '74.97'],
#   ['Gross Taxable Total', '0', '748.12'],
#   ['Tax (Incl Adjust)', '0', '-95'],
#   ['Net Pay', '0', '653.12'],
#   ['Superannuation', '0', '63.95']],
#  ['2/05/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '295.78'],
#   ['Annual Leave', '14', '285.58'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Leave Loading 17.5%', '0', '49.98'],
#   ['Gross Taxable Total', '0', '723.13'],
#   ['Tax (Incl Adjust)', '0', '-86'],
#   ['Net Pay', '0', '637.13'],
#   ['Superannuation', '0', '63.95']],
#  ['9/05/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['16/05/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['23/05/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['30/05/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['6/06/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['13/06/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '438.56'],
#   ['Other Leave - Public Holiday', '7', '142.79'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['20/06/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['27/06/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['4/07/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '581.35'],
#   ['60% Sun Perm Ldg', '7.5', '91.79'],
#   ['Gross Taxable Total', '0', '673.14'],
#   ['Tax (Incl Adjust)', '0', '-74'],
#   ['Net Pay', '0', '599.14'],
#   ['Superannuation', '0', '63.95']],
#  ['11/07/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['18/07/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['25/07/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28', '590'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '684.82'],
#   ['Tax (Incl Adjust)', '0', '-76'],
#   ['Net Pay', '0', '608.82'],
#   ['Superannuation', '0', '65.06']],
#  ['1/08/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['8/08/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['15/08/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['22/08/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '453.04'],
#   ['Sick Leave', '7', '147.5'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.36'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.36'],
#   ['Superannuation', '0', '66.06']],
#  ['29/08/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '305.54'],
#   ['Annual Leave', '14', '295'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Leave Loading 17.5%', '0', '51.62'],
#   ['Gross Taxable Total', '0', '746.98'],
#   ['Tax (Incl Adjust)', '0', '-94'],
#   ['Net Pay', '0', '652.98'],
#   ['Superannuation', '0', '66.06']],
#  ['5/09/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['12/09/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '305.54'],
#   ['Annual Leave', '14', '295'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Leave Loading 17.5%', '0', '51.62'],
#   ['Gross Taxable Total', '0', '746.98'],
#   ['Tax (Incl Adjust)', '0', '-94'],
#   ['Net Pay', '0', '652.98'],
#   ['Superannuation', '0', '66.06']],
#  ['19/09/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['26/09/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['3/10/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '453.04'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Public Holiday - worked', '7.5', '355.58'],
#   ['Gross Taxable Total', '0', '903.44'],
#   ['Tax (Incl Adjust)', '0', '-149'],
#   ['Net Pay', '0', '754.44'],
#   ['Superannuation', '0', '85.83']],
#  ['10/10/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['17/10/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '29', '611.07'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '705.89'],
#   ['Tax (Incl Adjust)', '0', '-81'],
#   ['Net Pay', '0', '624.89'],
#   ['Superannuation', '0', '67.06']],
#  ['24/10/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['31/10/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['7/11/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '25', '526.79'],
#   ['Annual Leave', '3.5', '73.75'],
#   ['60% Sun Perm Ldg', '4', '50.57'],
#   ['Leave Loading 17.5%', '0', '12.91'],
#   ['Gross Taxable Total', '0', '664.02'],
#   ['Tax (Incl Adjust)', '0', '-72'],
#   ['Net Pay', '0', '592.02'],
#   ['Superannuation', '0', '61.86']],
#  ['14/11/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['21/11/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['28/11/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '17', '358.21'],
#   ['Annual Leave', '7', '147.5'],
#   ['60% Sun Perm Ldg', '3', '37.93'],
#   ['Leave Loading 17.5%', '0', '25.81'],
#   ['Gross Taxable Total', '0', '569.45'],
#   ['Tax (Incl Adjust)', '0', '-52'],
#   ['Net Pay', '0', '517.45'],
#   ['Superannuation', '0', '51.65']],
#  ['5/12/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '453.04'],
#   ['Annual Leave', '7', '147.5'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Leave Loading 17.5%', '0', '25.81'],
#   ['Gross Taxable Total', '0', '721.17'],
#   ['Tax (Incl Adjust)', '0', '-86'],
#   ['Net Pay', '0', '635.17'],
#   ['Superannuation', '0', '66.06']],
#  ['12/12/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '453.04'],
#   ['Annual Leave', '7', '147.5'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Leave Loading 17.5%', '0', '25.81'],
#   ['Gross Taxable Total', '0', '721.17'],
#   ['Tax (Incl Adjust)', '0', '-86'],
#   ['Net Pay', '0', '635.17'],
#   ['Superannuation', '0', '66.06']],
#  ['19/12/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['26/12/1983',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '453.04'],
#   ['Other Leave - Public Holiday', '7', '147.5'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.36'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.36'],
#   ['Superannuation', '0', '66.06']],
#  ['2/01/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '453.04'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Public Holiday - worked', '7.5', '355.58'],
#   ['Gross Taxable Total', '0', '903.44'],
#   ['Tax (Incl Adjust)', '0', '-149'],
#   ['Net Pay', '0', '754.44'],
#   ['Superannuation', '0', '85.83']],
#  ['9/01/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['16/01/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['23/01/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['30/01/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Annual Leave', '21.5', '453.04'],
#   ['Other Leave - Birthday', '7', '147.5'],
#   ['Leave Loading 17.5%', '0', '79.28'],
#   ['Gross Taxable Total', '0', '679.82'],
#   ['Tax (Incl Adjust)', '0', '-75'],
#   ['Net Pay', '0', '604.82'],
#   ['Superannuation', '0', '57.05']],
#  ['6/02/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '14.5', '305.54'],
#   ['Annual Leave', '14', '295'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Leave Loading 17.5%', '0', '51.62'],
#   ['Gross Taxable Total', '0', '746.98'],
#   ['Tax (Incl Adjust)', '0', '-94'],
#   ['Net Pay', '0', '652.98'],
#   ['Superannuation', '0', '66.06']],
#  ['13/02/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21', '442.5'],
#   ['Annual Leave', '7.5', '158.04'],
#   ['Leave Loading 17.5%', '0', '27.66'],
#   ['Gross Taxable Total', '0', '628.2'],
#   ['Tax (Incl Adjust)', '0', '-65'],
#   ['Net Pay', '0', '563.2'],
#   ['Superannuation', '0', '57.05']],
#  ['20/02/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['27/02/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['6/03/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['13/03/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '453.04'],
#   ['Other Leave - Public Holiday', '7', '147.5'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.36'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.36'],
#   ['Superannuation', '0', '66.06']],
#  ['20/03/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['27/03/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['3/04/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '21.5', '453.04'],
#   ['Other Leave - Public Holiday', '7', '147.5'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.36'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.36'],
#   ['Superannuation', '0', '66.06']],
#  ['10/04/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
#   ['Tax (Incl Adjust)', '0', '-79'],
#   ['Net Pay', '0', '616.35'],
#   ['Superannuation', '0', '66.06']],
#  ['17/04/1984',
#   '004NASHK',
#   'Kristy Nash',
#   ['Normal Hours', '28.5', '600.53'],
#   ['60% Sun Perm Ldg', '7.5', '94.82'],
#   ['Gross Taxable Total', '0', '695.35'],
# ...
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['5/12/1983',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Reimburse expenses', '0', '50'],
#   ['Net Pay', '0', '783.16'],
#   ['Superannuation', '0', '82.76']],
#  ['12/12/1983',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['19/12/1983',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['26/12/1983',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '24.5', '533.58'],
#   ['Other Leave - Public Holiday', '15.5', '337.57'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.15'],
#   ['Superannuation', '0', '82.76']],
#  ['2/01/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '32', '696.92'],
#   ['Other Leave - Public Holiday', '8', '174.23'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.15'],
#   ['Superannuation', '0', '82.76']],
#  ['9/01/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '15.5', '337.57'],
#   ['Annual Leave', '24.5', '533.58'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.15'],
#   ['Superannuation', '0', '82.76']],
#  ['16/01/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['23/01/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['30/01/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '32', '696.92'],
#   ['Other Leave - Public Holiday', '8', '174.23'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.15'],
#   ['Superannuation', '0', '82.76']],
#  ['6/02/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '30', '653.37'],
#   ['Other Leave - Jury Duty', '10', '217.79'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Jury Duty Subsidy', '0', '-40'],
#   ['Net Pay', '0', '693.16'],
#   ['Superannuation', '0', '62.07']],
#  ['13/02/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '28.5', '620.7'],
#   ['Other Leave - Jury Duty', '11.5', '250.45'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Jury Duty Subsidy', '0', '-40'],
#   ['Net Pay', '0', '693.15'],
#   ['Superannuation', '0', '58.97']],
#  ['20/02/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '18.25', '397.46'],
#   ['Other Leave - Jury Duty', '21.75', '473.69'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Jury Duty Subsidy', '0', '-60'],
#   ['Net Pay', '0', '673.15'],
#   ['Superannuation', '0', '37.76']],
#  ['27/02/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '12.5', '272.24'],
#   ['Other Leave - Jury Duty', '21.25', '462.81'],
#   ['Gross Taxable Total', '0', '735.05'],
#   ['Tax (Incl Adjust)', '0', '-90'],
#   ['Jury Duty Subsidy', '0', '-60'],
#   ['Net Pay', '0', '585.05'],
#   ['Superannuation', '0', '25.86']],
#  ['6/03/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '8.75', '190.57'],
#   ['Other Leave - Leave w/out pay- with accr', '31.25', '0'],
#   ['uals', nan, nan],
#   ['Gross Taxable Total', '0', '190.57'],
#   ['Tax (Incl Adjust)', '0', '0'],
#   ['Net Pay', '0', '190.57']],
#  ['13/03/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '6.5', '141.56'],
#   ['Other Leave - Leave w/out pay- with accr', '25', '0'],
#   ['uals', nan, nan],
#   ['Other Leave - Public Holiday', '8.5', '185.12'],
#   ['Gross Taxable Total', '0', '326.68'],
#   ['Tax (Incl Adjust)', '0', '0'],
#   ['Net Pay', '0', '326.68'],
#   ['Superannuation', '0', '49.14']],
#  ['20/03/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '6', '130.67'],
#   ['Other Leave - Leave w/out pay- with accr', '34', '0'],
#   ['uals', nan, nan],
#   ['Gross Taxable Total', '0', '130.67'],
#   ['Tax (Incl Adjust)', '0', '0'],
#   ['Net Pay', '0', '130.67'],
#   ['Superannuation', '0', '12.41']],
#  ['27/03/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '25', '544.47'],
#   ['Other Leave - Leave w/out pay- with accr', '15', '0'],
#   ['uals', nan, nan],
#   ['Gross Taxable Total', '0', '544.47'],
#   ['Tax (Incl Adjust)', '0', '-47'],
#   ['Net Pay', '0', '497.47'],
#   ['Superannuation', '0', '51.72']],
#  ['3/04/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '24.5', '533.58'],
#   ['Other Leave - Public Holiday', '15.5', '337.57'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.15'],
#   ['Superannuation', '0', '82.76']],
#  ['10/04/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['17/04/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['24/04/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '25', '544.47'],
#   ['Annual Leave', '15', '326.68'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.15'],
#   ['Superannuation', '0', '82.76']],
#  ['1/05/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '15', '326.68'],
#   ['Annual Leave', '7.5', '163.34'],
#   ['Other Leave - Birthday', '8.5', '185.12'],
#   ['Other Leave - Public Holiday', '9', '196.01'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Reimburse expenses- Flu Vax', '0', '6'],
#   ['Net Pay', '0', '739.15'],
#   ['Superannuation', '0', '82.76']],
#  ['8/05/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['15/05/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['22/05/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['29/05/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['5/06/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['12/06/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '32.5', '707.81'],
#   ['Other Leave - Public Holiday', '7.5', '163.34'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.15'],
#   ['Superannuation', '0', '82.76']],
#  ['19/06/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['26/06/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '32.5', '707.81'],
#   ['Sick Leave', '7.5', '163.34'],
#   ['Gross Taxable Total', '0', '871.15'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.15'],
#   ['Superannuation', '0', '82.76']],
#  ['3/07/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '871.16'],
#   ['Gross Taxable Total', '0', '871.16'],
#   ['Tax (Incl Adjust)', '0', '-138'],
#   ['Net Pay', '0', '733.16'],
#   ['Superannuation', '0', '82.76']],
#  ['10/07/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '25', '563.22'],
#   ['Annual Leave', '15', '337.94'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['17/07/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '15', '337.93'],
#   ['Annual Leave', '25', '563.23'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['24/07/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['31/07/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['7/08/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['14/08/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['21/08/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['28/08/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['4/09/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['11/09/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['18/09/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['25/09/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['2/10/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '25', '563.22'],
#   ['Annual Leave', '7.5', '168.97'],
#   ['Other Leave - Public Holiday', '7.5', '168.97'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['9/10/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '15', '337.93'],
#   ['Annual Leave', '25', '563.23'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['16/10/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['23/10/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '35.75', '805.41'],
#   ['Sick Leave', '4.25', '95.75'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['30/10/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['6/11/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['13/11/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['20/11/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['27/11/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['4/12/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['11/12/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['18/12/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['25/12/1984',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '25', '563.22'],
#   ['Annual Leave', '7.5', '168.97'],
#   ['Other Leave - Public Holiday', '7.5', '168.97'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['1/01/1985',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Annual Leave', '23.5', '529.44'],
#   ['Other Leave - Public Holiday', '16.5', '371.73'],
#   ['Gross Taxable Total', '0', '901.17'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.17'],
#   ['Superannuation', '0', '85.61']],
#  ['8/01/1985',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '15', '337.93'],
#   ['Annual Leave', '25', '563.23'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['15/01/1985',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['22/01/1985',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '40', '901.16'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ['29/01/1985',
#   '013DIXOM',
#   'Mauro Dixon',
#   ['Normal Hours', '32.5', '732.19'],
#   ['Other Leave - Public Holiday', '7.5', '168.97'],
#   ['Gross Taxable Total', '0', '901.16'],
#   ['Tax (Incl Adjust)', '0', '-148'],
#   ['Net Pay', '0', '753.16'],
#   ['Superannuation', '0', '85.61']],
#  ...]

# %%
# List of unique features
features
# Out:
# ['Normal Hours',
#  'Gross Taxable Total',
#  'Tax (Incl Adjust)',
#  'Net Pay',
#  'Superannuation',
#  'Public Holiday - worked',
#  'Time/Half Hours',
#  'Reimburse expenses',
#  'Uniforms - Reducing Balance',
#  'Sat Casual Ldg',
#  'Other Leave - Public Holiday',
#  'Annual Leave',
#  'Sick Leave',
#  'Other Leave - Birthday',
#  'Term AL Gross',
#  'Account Payment',
#  '60% Sun Perm Ldg',
#  'Leave Loading 17.5%',
#  'Sunday Ldg',
#  'Other Leave - Unpaid Leave- No accruals',
#  'Long Service Leave',
#  'Term LL Gross',
#  'ETP - Taxable (Post June 83) Code : O',
#  '   Gratuity',
#  'Sat Perm Loading',
#  'Term LSL Gross',
#  'Sun Cas Ldg',
#  'Other Leave - Jury Duty',
#  'Jury Duty Subsidy',
#  'Reimburse expenses- Flu Vax',
#  'Other Leave - Bereavement',
#  'Other Leave - Leave w/out pay- with accr',
#  'uals',
#  'SUPER SUPER VOL CONT $',
#  "ZZZFirst Aid -hourly retail award (don't us",
#  'e)',
#  'First Aid- Retail award - wkly',
#  'First Aid - Retail Hourly Rate',
#  'Re-imburse expense - Safety Boots',
#  'Other Leave - Sick Leave - No accrual',
#  'Over Award',
#  '   Tax Adjustment',
#  'Key Allowance',
#  'Loan Repayments - Reducing balance',
#  'Salary Sacrifice - YSI Life',
#  'Salary Sacrifice - Super Superannuation',
#  'Other Leave - Workcover- lve accrued',
#  'Bonus',
#  'Salary Sacrifice - Carcosan Super',
#  'Other Leave - Compassionate',
#  'Other Leave - Paternity Leave- 1 wk paid']

# %% [markdown]
# Having 51 + 3 (ID, name, date) features is just not good, it increases complexity unnecessarily, and of course the curse of dimensionality plays here. We can decide which features to include in the table. Some can be aggregated, e.g. all leaves can be on "Leave", so let's look at which ones we can.
#
# Sure inclusions (not in order) excluding the 3:
# 1. Normal Hours
# 2. Gross Taxable Total
# 3. Tax
# 4. Net Pay
# 5. Superannuation
#
#
# To include some clarity for the reader, we can add another column called "Other description", which will have "First Aid", "Reimburse expenses", etc, while the numerical pay for these are included in "Other".
#
# Changes:
# 1. uals and e) are disregarded.
# 2. Leaves will include:
#     - Annual Leave
#     - Sick Leave
#     - Other Leave - Leave w/out pay- with accr
#     - Other Leave - Birthday
#     - Other Leave - Bereavement
#     - Other Leave - Paternity Leave- 1 wk paid
#     - Other Leave - Compassionate
#     - Other Leave - Workcover- lve accrued
#     - Other Leave - Unpaid Leave- No accruals
#     - Other Leave - Sick Leave - No accrual
# 3. Loading:
#     - Sat Casual Ldg
#     - 60% Sun Perm Ldg
#     - Sat Perm Loading
#     - Sun Cas Ldg
#     - Leave Loading 17.5%
#     - Sun ldg
# 4. Half hours can be added to normal hours.
# 5. It is arguable whether tax adjustment can be removed. If it is removed, the information of the total tax is still available and is essentially what is needed. If it is not, it is going to be a waste of space.
# 6.
#
# Final inclusions:
# 1. Normal Hours
# 2. Gross Taxable Total
# 3. Tax
# 4. Other
# 5. Net Pay
# 6. Leave
# 7. Loading (?)
# 8. Superannuation
# 9. Other description
#
# Note:
# I don't think a Payroll ID is needed as each pay is unique to an employee and their week of pay.

# %%
leave = ['Annual Leave', 'Sick Leave', 'Other Leave - Leave w/out pay- with accr', 'Other Leave - Birthday',
         'Other Leave - Bereavement', 'Other Leave - Paternity Leave- 1 wk paid', 'Other Leave - Compassionate',
         'Other Leave - Workcover- lve accrued', 'Other Leave - Unpaid Leave- No accruals', 'Other Leave - Sick Leave - No accrual', 'Other Leave - Public Holiday']

loading = ['Sat Casual Ldg', '60% Sun Perm Ldg', 'Sat Perm Loading', 'Sun Cas Ldg', 'Leave Loading 17.5%', 'Sun ldg']
core = ['Normal Hours', "Gross Taxable Total", 'Tax (Incl Adjust)', 'Net Pay', 'Superannuation']
useless = ['uals', 'e)', '   Tax Adjustment']

#It is always cheaper to collect data into a list or a list of lists or a list of dicts, and append all to a dataframe, than initializing an empty dataframe and appending row by row. 
# Therefore my function will be based off of that.

clean_entries = []
def CleanEntries(entries): #Function to make entries into a dictionary
    for ent in entries:
        entry = {'WeeklyPayDate' : np.nan, 
                'EmployeeID' : np.nan,
                'EmployeeName' : np.nan, 
                'Normal Hours' : 0, 
                'Normal Hours Amount' : 0, 
                'Leave': 0, 
                'LeaveAmount' : 0, 
                'Loading' : 0,
                'LoadingAmount' : 0,
                'Other' : 0,
                'OtherAmount' : 0,
                'Gross Taxable Total' : 0,
                'Tax (Incl Adjust)' : 0,
                'Net Pay' : 0,
                'Superannuation' : 0,
                'OtherDesc' : []} # Initialize numerical columns to 0, so that when one employee has multiple leaves or loadings, they will be added together.
        
        entry['WeeklyPayDate'] = ent[0]
        entry['EmployeeID'] = ent[1]
        entry['EmployeeName'] = ent[2]
        
        for i in range(3, len(ent)):
            if ent[i][0] in core:
                if ent[i][0] == 'Normal Hours':
                    entry['Normal Hours'] += float(ent[i][1])
                    entry['Normal Hours Amount'] += float(ent[i][2])
                else:
                    entry[ent[i][0]] += float(ent[i][2])
            
            elif ent[i][0] in leave:
                entry['Leave'] += float(ent[i][1])
                entry['LeaveAmount'] += float(ent[i][2])
                entry['OtherDesc'].append(ent[i][0])  #OtherDesc to increase awareness
            
            elif ent[i][0] in loading:
                entry['Loading'] += float(ent[i][1])
                entry['LoadingAmount'] += float(ent[i][2])
                entry['OtherDesc'].append(ent[i][0])
            
            elif ent[i][0] in useless:
                continue
            
            else:
                entry['Other'] += float(ent[i][1])
                entry['OtherAmount'] += float(ent[i][2])
                entry['OtherDesc'].append(ent[i][0])
        clean_entries.append(entry)

# %%
CleanEntries(entries)

# %%
# As planned

clean_entries
# Out:
# [{'WeeklyPayDate': '6/12/1982',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 23.0,
#   'Normal Hours Amount': 351.87,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 351.87,
#   'Tax (Incl Adjust)': 0.0,
#   'Net Pay': 351.87,
#   'Superannuation': 0,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '13/12/1982',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 46.0,
#   'Normal Hours Amount': 703.74,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 703.74,
#   'Tax (Incl Adjust)': -80.0,
#   'Net Pay': 623.74,
#   'Superannuation': 66.86,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '20/12/1982',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 37.5,
#   'Normal Hours Amount': 573.7,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 573.7,
#   'Tax (Incl Adjust)': -53.0,
#   'Net Pay': 520.7,
#   'Superannuation': 54.5,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '27/12/1982',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 30.0,
#   'Normal Hours Amount': 458.96,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 15.0,
#   'OtherAmount': 573.7,
#   'Gross Taxable Total': 1032.66,
#   'Tax (Incl Adjust)': -194.0,
#   'Net Pay': 838.66,
#   'Superannuation': 98.1,
#   'OtherDesc': ['Public Holiday - worked']},
#  {'WeeklyPayDate': '3/01/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 37.5,
#   'Normal Hours Amount': 573.7,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 573.7,
#   'Tax (Incl Adjust)': -53.0,
#   'Net Pay': 520.7,
#   'Superannuation': 54.5,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '10/01/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 32.0,
#   'Normal Hours Amount': 489.56,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 5.5,
#   'OtherAmount': 126.21,
#   'Gross Taxable Total': 615.77,
#   'Tax (Incl Adjust)': -62.0,
#   'Net Pay': 553.77,
#   'Superannuation': 46.51,
#   'OtherDesc': ['Time/Half Hours']},
#  {'WeeklyPayDate': '17/01/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 31.0,
#   'Normal Hours Amount': 474.26,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 474.26,
#   'Tax (Incl Adjust)': -29.0,
#   'Net Pay': 445.26,
#   'Superannuation': 45.05,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '24/01/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 37.0,
#   'Normal Hours Amount': 566.05,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 566.05,
#   'Tax (Incl Adjust)': -52.0,
#   'Net Pay': 514.05,
#   'Superannuation': 53.77,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '31/01/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 33.5,
#   'Normal Hours Amount': 512.51,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 512.51,
#   'Tax (Incl Adjust)': -40.0,
#   'Net Pay': 472.51,
#   'Superannuation': 48.69,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '7/02/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 35.5,
#   'Normal Hours Amount': 543.1,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0.0,
#   'OtherAmount': 50.0,
#   'Gross Taxable Total': 543.1,
#   'Tax (Incl Adjust)': -47.0,
#   'Net Pay': 546.1,
#   'Superannuation': 51.59,
#   'OtherDesc': ['Reimburse expenses']},
#  {'WeeklyPayDate': '14/02/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 35.25,
#   'Normal Hours Amount': 539.28,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 539.28,
#   'Tax (Incl Adjust)': -46.0,
#   'Net Pay': 493.28,
#   'Superannuation': 51.23,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '21/02/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 34.5,
#   'Normal Hours Amount': 527.81,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 527.81,
#   'Tax (Incl Adjust)': -43.0,
#   'Net Pay': 484.81,
#   'Superannuation': 50.14,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '28/02/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 35.25,
#   'Normal Hours Amount': 539.28,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 539.28,
#   'Tax (Incl Adjust)': -46.0,
#   'Net Pay': 493.28,
#   'Superannuation': 51.23,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '7/03/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 35.5,
#   'Normal Hours Amount': 543.1,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 543.1,
#   'Tax (Incl Adjust)': -47.0,
#   'Net Pay': 496.1,
#   'Superannuation': 51.59,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '14/03/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 35.5,
#   'Normal Hours Amount': 543.1,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 543.1,
#   'Tax (Incl Adjust)': -47.0,
#   'Net Pay': 496.1,
#   'Superannuation': 51.59,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '21/03/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 35.5,
#   'Normal Hours Amount': 543.1,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0.0,
#   'OtherAmount': -11.0,
#   'Gross Taxable Total': 543.1,
#   'Tax (Incl Adjust)': -47.0,
#   'Net Pay': 485.1,
#   'Superannuation': 51.59,
#   'OtherDesc': ['Uniforms - Reducing Balance']},
#  {'WeeklyPayDate': '28/03/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 32.0,
#   'Normal Hours Amount': 529.08,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0.0,
#   'OtherAmount': -11.0,
#   'Gross Taxable Total': 529.08,
#   'Tax (Incl Adjust)': -44.0,
#   'Net Pay': 474.08,
#   'Superannuation': 50.26,
#   'OtherDesc': ['Uniforms - Reducing Balance']},
#  {'WeeklyPayDate': '4/04/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 33.25,
#   'Normal Hours Amount': 593.47,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0.0,
#   'OtherAmount': -11.0,
#   'Gross Taxable Total': 593.47,
#   'Tax (Incl Adjust)': -57.0,
#   'Net Pay': 525.47,
#   'Superannuation': 56.38,
#   'OtherDesc': ['Uniforms - Reducing Balance']},
#  {'WeeklyPayDate': '11/04/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 41.5,
#   'Normal Hours Amount': 740.71,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 740.71,
#   'Tax (Incl Adjust)': -92.0,
#   'Net Pay': 648.71,
#   'Superannuation': 70.37,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '18/04/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 16.5,
#   'Normal Hours Amount': 294.5,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 8.5,
#   'OtherAmount': 379.28,
#   'Gross Taxable Total': 673.78,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.78,
#   'Superannuation': 64.01,
#   'OtherDesc': ['Public Holiday - worked']},
#  {'WeeklyPayDate': '25/04/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 41.75,
#   'Normal Hours Amount': 745.17,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 745.17,
#   'Tax (Incl Adjust)': -94.0,
#   'Net Pay': 651.17,
#   'Superannuation': 70.79,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '2/05/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 25.0,
#   'Normal Hours Amount': 446.21,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 446.21,
#   'Tax (Incl Adjust)': -21.0,
#   'Net Pay': 425.21,
#   'Superannuation': 0,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '9/05/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 34.0,
#   'Normal Hours Amount': 606.85,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 606.85,
#   'Tax (Incl Adjust)': -60.0,
#   'Net Pay': 546.85,
#   'Superannuation': 100.04,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '16/05/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 34.0,
#   'Normal Hours Amount': 606.85,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 606.85,
#   'Tax (Incl Adjust)': -60.0,
#   'Net Pay': 546.85,
#   'Superannuation': 57.65,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '23/05/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 14.5,
#   'Normal Hours Amount': 258.8,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 258.8,
#   'Tax (Incl Adjust)': 0.0,
#   'Net Pay': 258.8,
#   'Superannuation': 24.59,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '30/05/1983',
#   'EmployeeID': '001POWED',
#   'EmployeeName': 'Dominick Powers',
#   'Normal Hours': 25.0,
#   'Normal Hours Amount': 446.21,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 446.21,
#   'Tax (Incl Adjust)': -21.0,
#   'Net Pay': 425.21,
#   'Superannuation': 42.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '16/04/1985',
#   'EmployeeID': '002MORIC',
#   'EmployeeName': 'Crystal Morin',
#   'Normal Hours': 46.0,
#   'Normal Hours Amount': 1003.22,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 1003.22,
#   'Tax (Incl Adjust)': -85.0,
#   'Net Pay': 918.22,
#   'Superannuation': 95.3,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '23/04/1985',
#   'EmployeeID': '002MORIC',
#   'EmployeeName': 'Crystal Morin',
#   'Normal Hours': 19.5,
#   'Normal Hours Amount': 425.27,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 425.27,
#   'Tax (Incl Adjust)': -14.0,
#   'Net Pay': 411.27,
#   'Superannuation': 40.4,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '30/04/1985',
#   'EmployeeID': '002MORIC',
#   'EmployeeName': 'Crystal Morin',
#   'Normal Hours': 30.0,
#   'Normal Hours Amount': 654.27,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 8.5,
#   'LoadingAmount': 14.83,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 669.1,
#   'Tax (Incl Adjust)': -73.0,
#   'Net Pay': 596.1,
#   'Superannuation': 63.56,
#   'OtherDesc': ['Sat Casual Ldg']},
#  {'WeeklyPayDate': '7/05/1985',
#   'EmployeeID': '002MORIC',
#   'EmployeeName': 'Crystal Morin',
#   'Normal Hours': 4.0,
#   'Normal Hours Amount': 87.24,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 87.24,
#   'Tax (Incl Adjust)': 0.0,
#   'Net Pay': 87.24,
#   'Superannuation': 0,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '5/07/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 792.31,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 792.31,
#   'Tax (Incl Adjust)': -110.0,
#   'Net Pay': 682.31,
#   'Superannuation': 75.27,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '12/07/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 792.31,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 792.31,
#   'Tax (Incl Adjust)': -110.0,
#   'Net Pay': 682.31,
#   'Superannuation': 75.27,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '19/07/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 792.31,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 792.31,
#   'Tax (Incl Adjust)': -110.0,
#   'Net Pay': 682.31,
#   'Superannuation': 75.27,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '26/07/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 792.31,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 792.31,
#   'Tax (Incl Adjust)': -110.0,
#   'Net Pay': 682.31,
#   'Superannuation': 75.27,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '2/08/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 792.31,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 792.31,
#   'Tax (Incl Adjust)': -110.0,
#   'Net Pay': 682.31,
#   'Superannuation': 75.27,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '9/08/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 792.31,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 792.31,
#   'Tax (Incl Adjust)': -110.0,
#   'Net Pay': 682.31,
#   'Superannuation': 75.27,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '16/08/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '23/08/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '30/08/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '6/09/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '13/09/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '20/09/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '27/09/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '4/10/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '11/10/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0.0,
#   'OtherAmount': 76.5,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 793.66,
#   'Superannuation': 80.39,
#   'OtherDesc': ['Reimburse expenses']},
#  {'WeeklyPayDate': '18/10/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '25/10/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '1/11/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '8/11/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '15/11/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '22/11/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '29/11/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '6/12/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '13/12/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '20/12/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '27/12/1982',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 32.0,
#   'Normal Hours Amount': 676.92,
#   'Leave': 8.0,
#   'LeaveAmount': 169.23,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.15,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.15,
#   'Superannuation': 80.38,
#   'OtherDesc': ['Other Leave - Public Holiday']},
#  {'WeeklyPayDate': '3/01/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '10/01/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '17/01/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '24/01/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '31/01/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '7/02/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 23.5,
#   'Normal Hours Amount': 497.12,
#   'Leave': 16.5,
#   'LeaveAmount': 349.04,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': ['Annual Leave']},
#  {'WeeklyPayDate': '14/02/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '21/02/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '28/02/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '7/03/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '14/03/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '21/03/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '28/03/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '4/04/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 30.0,
#   'Normal Hours Amount': 634.62,
#   'Leave': 10.0,
#   'LeaveAmount': 211.54,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': ['Sick Leave']},
#  {'WeeklyPayDate': '11/04/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0.0,
#   'OtherAmount': 14.95,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 732.11,
#   'Superannuation': 80.39,
#   'OtherDesc': ['Reimburse expenses']},
#  {'WeeklyPayDate': '18/04/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 32.0,
#   'Normal Hours Amount': 676.92,
#   'Leave': 8.0,
#   'LeaveAmount': 169.23,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.15,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.15,
#   'Superannuation': 80.38,
#   'OtherDesc': ['Other Leave - Public Holiday']},
#  {'WeeklyPayDate': '25/04/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '2/05/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '9/05/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 32.5,
#   'Normal Hours Amount': 687.5,
#   'Leave': 47.5,
#   'LeaveAmount': 1004.81,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 1692.31,
#   'Tax (Incl Adjust)': -444.0,
#   'Net Pay': 1248.31,
#   'Superannuation': 160.77,
#   'OtherDesc': ['Sick Leave', 'Annual Leave']},
#  {'WeeklyPayDate': '16/05/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.15,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.15,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.15,
#   'Superannuation': 80.38,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '23/05/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '30/05/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '6/06/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '13/06/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 32.0,
#   'Normal Hours Amount': 676.92,
#   'Leave': 8.0,
#   'LeaveAmount': 169.23,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.15,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.15,
#   'Superannuation': 80.38,
#   'OtherDesc': ['Other Leave - Birthday']},
#  {'WeeklyPayDate': '20/06/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '27/06/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '4/07/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '11/07/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 28.0,
#   'Normal Hours Amount': 592.31,
#   'Leave': 12.0,
#   'LeaveAmount': 253.85,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': ['Sick Leave']},
#  {'WeeklyPayDate': '18/07/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 846.16,
#   'Tax (Incl Adjust)': -129.0,
#   'Net Pay': 717.16,
#   'Superannuation': 80.39,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '25/07/1983',
#   'EmployeeID': '003DALTE',
#   'EmployeeName': 'Erma Dalton',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 846.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 196.83,
#   'OtherAmount': 2685.0600000000004,
#   'Gross Taxable Total': 5009.88,
#   'Tax (Incl Adjust)': -1585.0,
#   'Net Pay': 1946.22,
#   'Superannuation': 80.39,
#   'OtherDesc': ['Term AL Gross', 'Account Payment']},
#  {'WeeklyPayDate': '5/07/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 567.73,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 89.64,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 657.37,
#   'Tax (Incl Adjust)': -71.0,
#   'Net Pay': 586.37,
#   'Superannuation': 62.45,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '12/07/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 29.0,
#   'Normal Hours Amount': 591.55,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0.0,
#   'OtherAmount': 50.0,
#   'Gross Taxable Total': 683.34,
#   'Tax (Incl Adjust)': -76.0,
#   'Net Pay': 657.34,
#   'Superannuation': 64.92,
#   'OtherDesc': ['60% Sun Perm Ldg', 'Reimburse expenses']},
#  {'WeeklyPayDate': '19/07/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 21.0,
#   'Normal Hours Amount': 428.36,
#   'Leave': 7.5,
#   'LeaveAmount': 152.99,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 581.35,
#   'Tax (Incl Adjust)': -55.0,
#   'Net Pay': 526.35,
#   'Superannuation': 55.23,
#   'OtherDesc': ['Sick Leave']},
#  {'WeeklyPayDate': '26/07/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '2/08/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 25.5,
#   'Normal Hours Amount': 520.16,
#   'Leave': 3.0,
#   'LeaveAmount': 61.19,
#   'Loading': 4.5,
#   'LoadingAmount': 65.78999999999999,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 647.14,
#   'Tax (Incl Adjust)': -69.0,
#   'Net Pay': 578.14,
#   'Superannuation': 60.46,
#   'OtherDesc': ['Annual Leave', '60% Sun Perm Ldg', 'Leave Loading 17.5%']},
#  {'WeeklyPayDate': '9/08/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '16/08/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '23/08/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '30/08/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 14.5,
#   'Normal Hours Amount': 295.78,
#   'Leave': 14.0,
#   'LeaveAmount': 285.58,
#   'Loading': 7.5,
#   'LoadingAmount': 141.77,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 723.13,
#   'Tax (Incl Adjust)': -86.0,
#   'Net Pay': 637.13,
#   'Superannuation': 63.95,
#   'OtherDesc': ['Annual Leave', '60% Sun Perm Ldg', 'Leave Loading 17.5%']},
#  {'WeeklyPayDate': '6/09/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 14.5,
#   'Normal Hours Amount': 295.78,
#   'Leave': 14.0,
#   'LeaveAmount': 285.58,
#   'Loading': 7.5,
#   'LoadingAmount': 116.78,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 698.14,
#   'Tax (Incl Adjust)': -79.0,
#   'Net Pay': 619.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['Sick Leave',
#    'Annual Leave',
#    '60% Sun Perm Ldg',
#    'Leave Loading 17.5%']},
#  {'WeeklyPayDate': '13/09/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '20/09/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 27.5,
#   'Normal Hours Amount': 560.95,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 652.74,
#   'Tax (Incl Adjust)': -70.0,
#   'Net Pay': 582.74,
#   'Superannuation': 62.01,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '27/09/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '4/10/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 20.5,
#   'Normal Hours Amount': 418.17,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 6.5,
#   'LoadingAmount': 79.55,
#   'Other': 7.5,
#   'OtherAmount': 382.47,
#   'Gross Taxable Total': 880.19,
#   'Tax (Incl Adjust)': -141.0,
#   'Net Pay': 739.19,
#   'Superannuation': 83.62,
#   'OtherDesc': ['60% Sun Perm Ldg', 'Public Holiday - worked']},
#  {'WeeklyPayDate': '11/10/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 27.25,
#   'Normal Hours Amount': 555.85,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 647.64,
#   'Tax (Incl Adjust)': -69.0,
#   'Net Pay': 578.64,
#   'Superannuation': 61.53,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '18/10/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 29.25,
#   'Normal Hours Amount': 596.65,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 688.44,
#   'Tax (Incl Adjust)': -77.0,
#   'Net Pay': 611.44,
#   'Superannuation': 65.4,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '25/10/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 7.0,
#   'Normal Hours Amount': 142.79,
#   'Leave': 21.5,
#   'LeaveAmount': 438.57,
#   'Loading': 0.0,
#   'LoadingAmount': 26.77,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 608.13,
#   'Tax (Incl Adjust)': -60.0,
#   'Net Pay': 548.13,
#   'Superannuation': 55.23,
#   'OtherDesc': ['Sick Leave', 'Annual Leave', 'Leave Loading 17.5%']},
#  {'WeeklyPayDate': '1/11/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '8/11/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '15/11/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 21.0,
#   'Normal Hours Amount': 428.36,
#   'Leave': 7.5,
#   'LeaveAmount': 152.99,
#   'Loading': 0.0,
#   'LoadingAmount': 26.77,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 608.12,
#   'Tax (Incl Adjust)': -60.0,
#   'Net Pay': 548.12,
#   'Superannuation': 55.23,
#   'OtherDesc': ['Annual Leave', 'Leave Loading 17.5%']},
#  {'WeeklyPayDate': '22/11/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 26.5,
#   'Normal Hours Amount': 540.55,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 632.34,
#   'Tax (Incl Adjust)': -65.0,
#   'Net Pay': 567.34,
#   'Superannuation': 60.07,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '29/11/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '6/12/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '13/12/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 26.5,
#   'Normal Hours Amount': 540.55,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 5.5,
#   'LoadingAmount': 67.31,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 607.86,
#   'Tax (Incl Adjust)': -60.0,
#   'Net Pay': 547.86,
#   'Superannuation': 57.75,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '20/12/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '27/12/1982',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 14.0,
#   'Normal Hours Amount': 285.58,
#   'Leave': 7.5,
#   'LeaveAmount': 152.99,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 7.5,
#   'OtherAmount': 382.47,
#   'Gross Taxable Total': 821.04,
#   'Tax (Incl Adjust)': -120.0,
#   'Net Pay': 701.04,
#   'Superannuation': 78.0,
#   'OtherDesc': ['Other Leave - Public Holiday', 'Public Holiday - worked']},
#  {'WeeklyPayDate': '3/01/1983',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 14.0,
#   'Normal Hours Amount': 285.58,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 15.0,
#   'OtherAmount': 764.94,
#   'Gross Taxable Total': 1050.52,
#   'Tax (Incl Adjust)': -200.0,
#   'Net Pay': 850.52,
#   'Superannuation': 99.8,
#   'OtherDesc': ['Public Holiday - worked']},
#  {'WeeklyPayDate': '10/01/1983',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 21.5,
#   'Normal Hours Amount': 438.56,
#   'Leave': 7.0,
#   'LeaveAmount': 142.79,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['Sick Leave', '60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '17/01/1983',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 7.5,
#   'Normal Hours Amount': 152.99,
#   'Leave': 21.0,
#   'LeaveAmount': 428.37,
#   'Loading': 7.5,
#   'LoadingAmount': 166.76,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 748.12,
#   'Tax (Incl Adjust)': -95.0,
#   'Net Pay': 653.12,
#   'Superannuation': 63.95,
#   'OtherDesc': ['Annual Leave', '60% Sun Perm Ldg', 'Leave Loading 17.5%']},
#  {'WeeklyPayDate': '24/01/1983',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 14.5,
#   'Normal Hours Amount': 295.78,
#   'Leave': 14.0,
#   'LeaveAmount': 285.58,
#   'Loading': 7.5,
#   'LoadingAmount': 141.77,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 723.13,
#   'Tax (Incl Adjust)': -86.0,
#   'Net Pay': 637.13,
#   'Superannuation': 63.95,
#   'OtherDesc': ['Annual Leave', '60% Sun Perm Ldg', 'Leave Loading 17.5%']},
#  {'WeeklyPayDate': '31/01/1983',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 21.5,
#   'Normal Hours Amount': 438.56,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 7.5,
#   'OtherAmount': 382.47,
#   'Gross Taxable Total': 912.82,
#   'Tax (Incl Adjust)': -152.0,
#   'Net Pay': 760.82,
#   'Superannuation': 86.72,
#   'OtherDesc': ['60% Sun Perm Ldg', 'Public Holiday - worked']},
#  {'WeeklyPayDate': '7/02/1983',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 673.14,
#   'Tax (Incl Adjust)': -74.0,
#   'Net Pay': 599.14,
#   'Superannuation': 63.95,
#   'OtherDesc': ['60% Sun Perm Ldg']},
#  {'WeeklyPayDate': '14/02/1983',
#   'EmployeeID': '004NASHK',
#   'EmployeeName': 'Kristy Nash',
#   'Normal Hours': 28.5,
#   'Normal Hours Amount': 581.35,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 7.5,
#   'LoadingAmount': 91.79,
#   'Other': 0,
#   'OtherAmount': 0,
# ...
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 15.0,
#   'Normal Hours Amount': 326.68,
#   'Leave': 25.0,
#   'LeaveAmount': 544.47,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0.0,
#   'OtherAmount': 6.0,
#   'Gross Taxable Total': 871.15,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 739.15,
#   'Superannuation': 82.76,
#   'OtherDesc': ['Annual Leave',
#    'Other Leave - Birthday',
#    'Other Leave - Public Holiday',
#    'Reimburse expenses- Flu Vax']},
#  {'WeeklyPayDate': '8/05/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 871.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.16,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.16,
#   'Superannuation': 82.76,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '15/05/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 871.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.16,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.16,
#   'Superannuation': 82.76,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '22/05/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 871.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.16,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.16,
#   'Superannuation': 82.76,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '29/05/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 871.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.16,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.16,
#   'Superannuation': 82.76,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '5/06/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 871.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.16,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.16,
#   'Superannuation': 82.76,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '12/06/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 32.5,
#   'Normal Hours Amount': 707.81,
#   'Leave': 7.5,
#   'LeaveAmount': 163.34,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.15,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.15,
#   'Superannuation': 82.76,
#   'OtherDesc': ['Other Leave - Public Holiday']},
#  {'WeeklyPayDate': '19/06/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 871.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.16,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.16,
#   'Superannuation': 82.76,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '26/06/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 32.5,
#   'Normal Hours Amount': 707.81,
#   'Leave': 7.5,
#   'LeaveAmount': 163.34,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.15,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.15,
#   'Superannuation': 82.76,
#   'OtherDesc': ['Sick Leave']},
#  {'WeeklyPayDate': '3/07/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 871.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 871.16,
#   'Tax (Incl Adjust)': -138.0,
#   'Net Pay': 733.16,
#   'Superannuation': 82.76,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '10/07/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 25.0,
#   'Normal Hours Amount': 563.22,
#   'Leave': 15.0,
#   'LeaveAmount': 337.94,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Annual Leave']},
#  {'WeeklyPayDate': '17/07/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 15.0,
#   'Normal Hours Amount': 337.93,
#   'Leave': 25.0,
#   'LeaveAmount': 563.23,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Annual Leave']},
#  {'WeeklyPayDate': '24/07/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '31/07/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '7/08/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '14/08/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '21/08/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '28/08/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '4/09/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '11/09/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '18/09/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '25/09/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '2/10/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 25.0,
#   'Normal Hours Amount': 563.22,
#   'Leave': 15.0,
#   'LeaveAmount': 337.94,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Annual Leave', 'Other Leave - Public Holiday']},
#  {'WeeklyPayDate': '9/10/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 15.0,
#   'Normal Hours Amount': 337.93,
#   'Leave': 25.0,
#   'LeaveAmount': 563.23,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Annual Leave']},
#  {'WeeklyPayDate': '16/10/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '23/10/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 35.75,
#   'Normal Hours Amount': 805.41,
#   'Leave': 4.25,
#   'LeaveAmount': 95.75,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Sick Leave']},
#  {'WeeklyPayDate': '30/10/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '6/11/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '13/11/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '20/11/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '27/11/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '4/12/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '11/12/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '18/12/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '25/12/1984',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 25.0,
#   'Normal Hours Amount': 563.22,
#   'Leave': 15.0,
#   'LeaveAmount': 337.94,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Annual Leave', 'Other Leave - Public Holiday']},
#  {'WeeklyPayDate': '1/01/1985',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 0,
#   'Normal Hours Amount': 0,
#   'Leave': 40.0,
#   'LeaveAmount': 901.1700000000001,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.17,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.17,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Annual Leave', 'Other Leave - Public Holiday']},
#  {'WeeklyPayDate': '8/01/1985',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 15.0,
#   'Normal Hours Amount': 337.93,
#   'Leave': 25.0,
#   'LeaveAmount': 563.23,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Annual Leave']},
#  {'WeeklyPayDate': '15/01/1985',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '22/01/1985',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 40.0,
#   'Normal Hours Amount': 901.16,
#   'Leave': 0,
#   'LeaveAmount': 0,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': []},
#  {'WeeklyPayDate': '29/01/1985',
#   'EmployeeID': '013DIXOM',
#   'EmployeeName': 'Mauro Dixon',
#   'Normal Hours': 32.5,
#   'Normal Hours Amount': 732.19,
#   'Leave': 7.5,
#   'LeaveAmount': 168.97,
#   'Loading': 0,
#   'LoadingAmount': 0,
#   'Other': 0,
#   'OtherAmount': 0,
#   'Gross Taxable Total': 901.16,
#   'Tax (Incl Adjust)': -148.0,
#   'Net Pay': 753.16,
#   'Superannuation': 85.61,
#   'OtherDesc': ['Other Leave - Public Holiday']},
#  ...]

# %%
clean_entries_df = pd.DataFrame(clean_entries)

# %%
clean_entries_df.dtypes
# Out:
# WeeklyPayDate           object
# EmployeeID              object
# EmployeeName            object
# Normal Hours           float64
# Normal Hours Amount    float64
# Leave                  float64
# LeaveAmount            float64
# Loading                float64
# LoadingAmount          float64
# Other                  float64
# OtherAmount            float64
# Gross Taxable Total    float64
# Tax (Incl Adjust)      float64
# Net Pay                float64
# Superannuation         float64
# OtherDesc               object
# dtype: object

# %%
#Though there is merit in keeping the 'WeeklyPayDate' in datetime, it may affect readability as the convention for Australians is Day Month Year,
#and the original was in the form DD/MM/YYYY. Therefore:

clean_entries_df['WeeklyPayDate'] = pd.to_datetime(clean_entries_df['WeeklyPayDate'], format='%d/%m/%Y', dayfirst=True).dt.strftime('%d/%m/%Y')

# %%
# Standardize column names to PascalCase.

clean_entries_df = clean_entries_df.rename(columns={'Normal Hours':'NormalHours',
                                                    'Normal Hours Amount':'NormalHoursPay',
                                                    'Leave':'LeaveHours',
                                                    'LeaveAmount':'LeavePay',
                                                    'Loading':'LoadingHours',
                                                    'LoadingAmount':'LoadingPay',
                                                    'Other':'OtherHours',
                                                    'OtherAmount': 'OtherPay',
                                                    'Gross Taxable Total':'GrossTaxableTotal',
                                                    'Tax (Incl Adjust)':'AdjustedTax',
                                                    'Net Pay':'NetPay'})

# %%
# Round all numerical columns to 2 decimal places.

for col in clean_entries_df.columns:
    if clean_entries_df[col].dtype == 'float64':
        clean_entries_df[col] = clean_entries_df[col].round(2)

# %%
# Export as csv.
clean_entries_df.to_csv("/mnt/c/Users/user/TechAssessmentOutput.csv", index=False)
